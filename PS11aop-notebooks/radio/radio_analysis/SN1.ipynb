# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
# pd.read_csv("grizps11aop.csv")
#df1 = pd.read_csv('snradio1.csv') #reads in the upperlimit data parameters
df2 = pd.read_csv('sndetec.csv') #reads in the detected Luminosity data parameters
#df3 = pd.read_csv('radiomodel.csv') # reads in the radio model for testing data parameters
df4 = pd.read_csv('othersne.csv') #reads in the other SNe data parameters
#df5 = pd.read_csv('PS11aop.csv')


#excel_file = 'snradio1.xls'

#snradio = pd.read_excel(excel_file)dfa137 = pd.read_csv('/home/ibik/Documents/sndata/a137.csv')

# %%
#df1.columns=['Target', 'Obs. Date (MJD)','date of g-max', 'days', 'redshift', 'D(luminosity)', 'Flux/upper limits', 'Radioluminosity','logl','restdays','logrt','freqtime','logt']
df2.columns=['Target', 'Obs. Date (MJD)','date of g-max', 'days', 'redshift', 'D(luminosity)', 'Flux/upper limits', 'Radioluminosity','logl','freq','status','restdays','logr','freqtime','logt']
#df5.columns=['Target', 'Obs. Date (MJD)','date of g-max','date of g-max', 'days', 'redshift', 'D(luminosity)', 'Flux/upper limits', 'Radioluminosity','D(Mpc)','logdays','restdays','logrestdays','logl']
#df3.columns=['Astar','Time','Luminosity','logl','logt','flux','flux(mJy)'] 
df4.columns=['SN','time','DL','Flux(Jy)','Luminosity(erg/s/Hz)','logl','logrt','freqtime','logt']

# %%
#this code plots the other supernovae with the observed PS1 ones
#fig =plt.figure(figsize=(7,5))
markeredgecolor='k'
markeredgewidth=2
fig = plt.figure(figsize=(12,12))
from matplotlib import rc,rcParams
rc('font', weight='bold')
#plt.ylim(27,29.00)
#plt.xlim(250, 1750)
#plt.plot(df1['logt'], df1['logl'],'rv', markersize=12,markeredgecolor='k',markeredgewidth=2, label = 'upper limits PS1-SLSNe') # marker_color='r')
#plt.plot(df2['logt'][0], df2['logl'][0],'bo', markersize=15,markeredgecolor='k',markeredgewidth=2, label = 'PS11vo') # marker_color='b')
#plt.plot(df2['logt'], df2['logl'],'bo', markersize=10, label = 'PS1-SLSN') # marker_color='b')
#plt.plot(df4['logt'][0:4], df4['logl'][0:4],'mv-', markersize=10)# label = 'SNso') # marker_color='b')
plt.plot(3.53857373380686, 26.0413926851582,'mv', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1987B') #
plt.plot(3.45697301363582, 27.5051499783199,'mv', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1988I') #

plt.plot(3.3654879848909, 26.1461280356782,'mv', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1989C') #
plt.plot(3.42160392686983, 27.0413926851582,'mv', markersize=10,markeredgecolor='k',markeredgewidth=2)#label = 'SN1989R') #
#PS1-11aop
plt.plot(df2['logt'][1], df2['logl'][1],'*-',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2,label = 'PS1-11aop')
plt.plot(df2['logt'][2], df2['logl'][2],'*-',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2)#label = cband
#plt.plot(df2['logt'][3], df2['logl'][3],'v-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=2)#label = xband
plt.plot(df2['logt'][4], df2['logl'][4],'*-',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2)#label = kuband
D = 1070.1 # distance to SN in Mpc
plt.plot(df2['logt'][6], df2['logl'][6],'*',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2) # marker_color='b')
#plt.plot(df2['logt'][7], df2['logl'][7],'v-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=1) # marker_color='b')
#plt.plot(df2['logt'][8], df2['logl'][8],'v-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=1) # marker_color='b')
#plt.plot(df2['logt'][1:8], df2['logl'][1:8],'c-')

plt.plot(df4['logt'][5:8], df4['logl'][5:8],'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1978g') # marker_color='b')

plt.plot(df4['logt'][9:12], df4['logl'][9:12],'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2)# label = 'SN1983k') # marker_color='b')

plt.plot(df4['logt'][13:17], df4['logl'][13:17],'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1984E') # marker_color='b')

plt.plot(df4['logt'][18:22], df4['logl'][18:22],'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1987F') # marker_color='b')

plt.plot(df4['logt'][23:25], df4['logl'][23:25],'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1991ae') # marker_color='b')
plt.plot(df4['logt'][26:29], df4['logl'][26:29],'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1991ar') # marker_color='b')

plt.plot(df4['logt'][30:40], df4['logl'][30:40],'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2, label='SNe-IIn limits') #label = 'SN2006jd') # marker_color='b')

plt.plot(df4['logt'][41:56], df4['logl'][41:56],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2,label = 'SNe-IIn detections')
#plt.plot(df4['logt'][57:62], df4['logl'][57:62], marker = ko- mo- b0- ro-, markersize=10,label = 'SN2009ip') 

# marker_color='b')
plt.plot(df4['logt'][63:68], df4['logl'][63:68],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1998S') # marker_color='b')
plt.plot(df4['logt'][69:71], df4['logl'][69:71],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1978K') # marker_color='b')


#plt.plot(df4['time'][65:65], df4['logl'][65:65],'cp-', markersize=15, label = 'SN2005kd') # marker_color='b')
#plt.plot(609.44,30.0856090799178,'cs-', markersize=15, label = 'SN2005kd') # marker_color='b')
plt.plot(3.01537987669514, 27.0856090799178,'mo', markersize=10,markeredgecolor='k',markeredgewidth=2) # marker_color='b') #SN2005kd

plt.plot(df4['logt'][74:79], df4['logl'][74:79],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1986j') # marker_color='b')
plt.plot(df4['logt'][80:113], df4['logl'][80:113],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1988Z') # marker_color='b')

#plt.plot(df4['time'][85:97], df4['logl'][85:97],'m4-', markersize=15, label = 'SN1988Z_5GHz') # marker_color='b'

plt.plot(df4['logt'][115:117], df4['logl'][115:117],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1997eg_5GHz') # marker_color='b')
plt.plot(df4['logt'][118:125], df4['logl'][118:125],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2)#,label = 'SN2001em') # detection
plt.plot(df4['logt'][126:132], df4['logl'][126:132],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN2000ft_5GHz') # marker_color='b')
plt.plot(df4['logt'][133:138], df4['logl'][133:138],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN2000ft') # marker_color='b')
plt.plot(df4['logt'][139:145], df4['logl'][139:145],'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1996cr_5GHz') # marker_color='b')

#plt.yscale('log')
plt.xlabel('Log$_{10}$ t$_{rest}$ (days)($\u03BD$/5 GHz)', fontsize=30, fontweight='bold')
plt.ylabel('Log$_{10}$ Luminosity (erg $s^{-1}$ $Hz^{-1}$)', fontsize =30,fontweight='bold')
#plt.legend(frameon=True, framealpha=0.1, loc='center left', bbox_to_anchor=(1, 0.5),prop={'size': 10})
plt.legend(prop={'size': 20})#loc='center left', bbox_to_anchor=(1, 0.5))
#plt.show()
plt.tick_params(labelsize = 30)
#fig.savefig('SNelogf2_p.png',dpi = 300,transparent=True,bbox_inches='tight')
#plt.savefig('SNelogf2.pdf', , bbox_inches='tight')

# %%
#this code plots the other supernovae with the observed PS1 ones
#fig =plt.figure(figsize=(7,5))
markeredgecolor='k'
markeredgewidth=2
fig = plt.figure(figsize=(12,12))
from matplotlib import rc,rcParams
rc('font', weight='bold')
#plt.ylim(27,29.00)
#plt.xlim(250, 1750)
#plt.plot(df1['logt'], df1['logl'],'rv', markersize=12,markeredgecolor='k',markeredgewidth=2, label = 'upper limits PS1-SLSNe') # marker_color='r')
#plt.plot(df2['logt'][0], df2['logl'][0],'bo', markersize=15,markeredgecolor='k',markeredgewidth=2, label = 'PS11vo') # marker_color='b')
#plt.plot(df2['logt'], df2['logl'],'bo', markersize=10, label = 'PS1-SLSN') # marker_color='b')
#plt.plot(df4['logt'][0:4], df4['logl'][0:4],'mv-', markersize=10)# label = 'SNso') # marker_color='b')
plt.plot(10**(3.53857373380686), 10**(26.0413926851582),'mv', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1987B') #
plt.plot(10**(3.45697301363582), 10**(27.5051499783199),'mv', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1988I') #

plt.plot(10**(3.3654879848909), 10**(26.1461280356782),'mv', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1989C') #
plt.plot(10**(3.42160392686983), 10**(27.0413926851582),'mv', markersize=10,markeredgecolor='k',markeredgewidth=2)#label = 'SN1989R') #
#PS1-11aop
plt.plot(10**(df2['logt'][1]), 10**(df2['logl'][1]),'*-',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2,label = 'PS1-11aop')

plt.plot(10**(df2['logt'][2]), 10**(df2['logl'][2]),'*-',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2)#label = cband
#plt.plot(df2['logt'][3], df2['logl'][3],'v-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=2)#label = xband
plt.plot(10**(df2['logt'][4]), 10**(df2['logl'][4]),'*-',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2)#label = kuband
D = 1070.1 # distance to SN in Mpc
plt.plot(10**(df2['logt'][6]), 10**(df2['logl'][6]),'*',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2) # marker_color='b')
#plt.plot(df2['logt'][7], df2['logl'][7],'v-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=1) # marker_color='b')
#plt.plot(df2['logt'][8], df2['logl'][8],'v-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=1) # marker_color='b')
#plt.plot(df2['logt'][1:8], df2['logl'][1:8],'c-')

plt.plot(10**(df4['logt'][5:8]), 10**(df4['logl'][5:8]),'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1978g') # marker_color='b')

plt.plot(10**(df4['logt'][9:12]), 10**(df4['logl'][9:12]),'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2)# label = 'SN1983k') # marker_color='b')

plt.plot(10**(df4['logt'][13:17]), 10**(df4['logl'][13:17]),'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1984E') # marker_color='b')

plt.plot(10**(df4['logt'][18:22]), 10**(df4['logl'][18:22]),'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1987F') # marker_color='b')

plt.plot(10**(df4['logt'][23:25]), 10**(df4['logl'][23:25]),'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1991ae') # marker_color='b')
plt.plot(10**(df4['logt'][26:29]), 10**(df4['logl'][26:29]),'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1991ar') # marker_color='b')

plt.plot(10**(df4['logt'][30:40]), 10**(df4['logl'][30:40]),'mv-', markersize=10,markeredgecolor='k',markeredgewidth=2, label='SNe-IIn limits') #label = 'SN2006jd') # marker_color='b')

plt.plot(10**(df4['logt'][41:56]), 10**(df4['logl'][41:56]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2,label = 'SNe-IIn detections')
#plt.plot(df4['logt'][57:62], df4['logl'][57:62], marker = ko- mo- b0- ro-, markersize=10,label = 'SN2009ip') 

# marker_color='b')
plt.plot(10**(df4['logt'][63:68]), 10**(df4['logl'][63:68]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1998S') # marker_color='b')
plt.plot(10**(df4['logt'][69:71]), 10**(df4['logl'][69:71]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1978K') # marker_color='b')


#plt.plot(df4['time'][65:65], df4['logl'][65:65],'cp-', markersize=15, label = 'SN2005kd') # marker_color='b')
#plt.plot(609.44,30.0856090799178,'cs-', markersize=15, label = 'SN2005kd') # marker_color='b')
plt.plot(10**(3.01537987669514), 10**(27.0856090799178),'mo', markersize=10,markeredgecolor='k',markeredgewidth=2) # marker_color='b') #SN2005kd

plt.plot(10**(df4['logt'][74:79]), 10**(df4['logl'][74:79]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1986j') # marker_color='b')
plt.plot(10**(df4['logt'][80:113]), 10**(df4['logl'][80:113]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1988Z') # marker_color='b')

#plt.plot(df4['time'][85:97], df4['logl'][85:97],'m4-', markersize=15, label = 'SN1988Z_5GHz') # marker_color='b'

plt.plot(10**(df4['logt'][115:117]), 10**(df4['logl'][115:117]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1997eg_5GHz') # marker_color='b')
plt.plot(10**(df4['logt'][118:125]), 10**(df4['logl'][118:125]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2)#,label = 'SN2001em') # detection
plt.plot(10**(df4['logt'][126:132]), 10**(df4['logl'][126:132]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN2000ft_5GHz') # marker_color='b')
plt.plot(10**(df4['logt'][133:138]), 10**(df4['logl'][133:138]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN2000ft') # marker_color='b')
plt.plot(10**(df4['logt'][139:145]), 10**(df4['logl'][139:145]),'mo-', markersize=10,markeredgecolor='k',markeredgewidth=2) #label = 'SN1996cr_5GHz') # marker_color='b')

plt.yscale('log')
plt.xscale('log')
#plt.xlabel('Log$_{10}$ t$_{rest}$ (days)($\u03BD$/5 GHz)', fontsize=30,fontweight='bold')
#plt.ylabel('Log$_{10}$ Luminosity (erg $s^{-1}$ $Hz^{-1}$)', fontsize =30,fontweight='bold')
plt.xlabel('Time (days)($\u03BD$/5 GHz)', fontsize=30,fontweight='bold')
plt.ylabel('Luminosity (erg $s^{-1}$ $Hz^{-1}$)', fontsize =30,fontweight='bold')
#plt.legend(frameon=True, framealpha=0.1, loc='center left', bbox_to_anchor=(1, 0.5),prop={'size': 10})
plt.legend(prop={'size': 20})#loc='center left', bbox_to_anchor=(1, 0.5))
#plt.show()
plt.tick_params(labelsize = 30)
fig.savefig('SNelogf2_p.png',dpi = 300,transparent=True,bbox_inches='tight')
#plt.savefig('SNelogf2.pdf', , bbox_inches='tight')

# %%
#this code plots the first models for testing
plt.rcParams.update({'font.size': 20})

fig = plt.figure(figsize=(19.20,10.80))
plt.ylim(26,30.00)
plt.xlim(2.4, 3.8)
#plt.plot(df1['logt'], df1['logl'],'rv', markersize=15, label = 'upper limits PS1-SLSNe') # marker_color='r')

#plt.plot(df2['logt'][0], df2['logl'][0],'bo', markersize=15,markeredgecolor='k',markeredgewidth=2, label = 'PS11vo')
plt.plot(df2['logt'][1], df2['logl'][1],'o-',color = 'orange', markersize=20,markeredgecolor='k',markeredgewidth=2,label = 'PS11aop')
plt.plot(df2['logt'][2], df2['logl'][2],'o-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=2)#label = cband
plt.plot(df2['logt'][3], df2['logl'][3],'v-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=2)#label = xband
#plt.plot(df2['logt'][4], df2['logl'][4],'v-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=2)#label = sband
plt.plot(df2['logt'][4], df2['logl'][4],'o-',color = 'orange', markersize=15,markeredgecolor='k',markeredgewidth=2)#label = kuband

plt.plot(df2['logt'][5], df2['logl'][5],'o',color = 'orange', markersize=10,markeredgecolor='k',markeredgewidth=1) # marker_color='b')
plt.plot(df2['logt'][6], df2['logl'][6],'v-',color = 'orange', markersize=10,markeredgecolor='k',markeredgewidth=1) # marker_color='b')
plt.plot(df2['logt'][7], df2['logl'][7],'v-',color = 'orange', markersize=10,markeredgecolor='k',markeredgewidth=1) # marker_color='b')

# marker_color='b')

#plt.plot(df3['logt'][0:99], df3['logl'][0:99],'.-', alpha =0.5, label = 'A1') # marker_color='b')
#plt.plot(df3['logt'][100:199], df3['logl'][100:199],'*-', alpha =0.5, label = 'A2')
plt.plot(df3['logt'][200:299], df3['logl'][200:299],'C11', alpha =0.5, label = '$18.9 x 10^{-5} M_{\odot}$/yr') # 'A3')
#plt.plot(df3['logt'][300:399], df3['logl'][300:399],'^-', alpha =0.5, label = 'A4')
plt.plot(df3['logt'][400:499], df3['logl'][400:499],'g', alpha =0.5, label = '$35.6 x 10^{-5} M_{\odot}$/yr') #A5')
plt.plot(df3['logt'][500:599], df3['logl'][500:599],'k', alpha =0.5, label = '$48.9 x 10^{-5} M_{\odot}$/yr') #A6')
#plt.plot(df3['logt'][600:699], df3['logl'][600:699],'>-', alpha =0.5, label = 'A7')
#plt.plot(df3['logt'][700:799], df3['logl'][700:799],'o-', alpha =0.5, label = 'A8')
#plt.plot(df3['logt'][800:899], df3['logl'][800:899],'o-', alpha =0.5, label = 'A9')
#plt.plot(df3['logt'][900:999], df3['logl'][900:999],'o-', alpha =0.5, label = 'A10')
#plt.plot(df3['logt'][1000:1099], df3['logl'][1000:1099],'o-', alpha =0.5, label = 'A11')
#plt.plot(df3['logt'][1100:1199], df3['logl'][1100:1199],'*-', alpha =0.5, label = 'A12')
#plt.plot(df3['logt'][1200:1299], df3['logl'][1200:1299],'>-', alpha =0.5, label = 'A13')
#plt.plot(df3['logt'][1300:1399], df3['logl'][1300:1399],'o-', alpha =0.5, label = 'A14')
#plt.plot(df3['logt'][1400:1499], df3['logl'][1400:1499],'o-', alpha =0.5, label = 'A15')
plt.plot(df3['logt'][1500:1599], df3['logl'][1500:1599],'m', alpha =0.5, label = '$0.012 M_{\odot}$/yr') #A16')
#plt.plot(df3['logt'][1600:1699], df3['logl'][1600:1699],'o-', alpha =0.5, label = 'A17')
#plt.plot(df3['logt'][1700:1799], df3['logl'][1700:1799],'o-', alpha =0.5, label = 'A18')
plt.plot(df3['logt'][1800:1899], df3['logl'][1800:1899],'c', alpha =0.5, label = '$0.03 M_{\odot}$/yr') #A19')
#plt.plot(df3['logt'][1900:1999], df3['logl'][1900:1999],'o-', alpha =0.5, label = 'A20')
#plt.plot(df3['logt'][2000:2099], df3['logl'][2000:2099],'o-', alpha =0.5, label = 'A21')
plt.plot(df3['logt'][2100:2199], df3['logl'][2100:2199],'r', alpha =0.5, label = '$0.08 M_{\odot}$/yr') #' 'A22')
plt.plot(df3['logt'][2200:2299], df3['logl'][2200:2299],'b', alpha =0.5, label = '$0.1 M_{\odot}$/yr') #A23')
#plt.plot(df3['logt'][2300:2399], df3['logl'][2300:2399],'o-', alpha =0.5, label = 'A24')
#plt.plot(df3['logt'][2400:2499], df3['logl'][2400:2499],'o-', alpha =0.5, label = 'A25')
#plt.plot(df3['logt'][2500:2599], df3['logl'][2500:2599],'>-', alpha =0.5, label = 'A26')
#plt.plot(df3['logt'][2600:2699], df3['logl'][2600:2699],'>-', alpha =0.5, label = 'A27')
#plt.plot(df3['logt'][2700:2799], df3['logl'][2700:2799],'o-', alpha =0.5, label = 'A28')
#plt.plot(df3['logt'][2800:2899], df3['logl'][2800:2899],'>-', alpha =0.5, label = 'A29')
#plt.plot(df3['logt'][2900:2999], df3['logl'][2900:2999],'o-', alpha =0.5, label = 'A30')


plt.xlabel('Log$_{10}$ t$_{rest}$(days)',fontsize=30) #('Rest Frame Days post-explosion (days)', fontsize=14)
plt.ylabel('Log$_{10}$ L (erg $s^{-1}$ $Hz^{-1}$)', fontsize =30)
plt.legend(loc='upper left') #frameon=True, framealpha=0.1, loc='center left', bbox_to_anchor=(1, 0.5),prop={'size': 15})
#ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.show()
fig.savefig('snradmodellog2_b.png', dpi =300, transparent =True)
#plt.savefig('snradmodellog2.pdf', bbox_inches='tight',)

# %% [markdown]
# ## Radio Luminosities of PS1-11aop

# %%
#first epoch
#4.550460313335275e+28 +/- 1.752

#second epoch
#3.572954023803994e+28 +/- 2.134
#1.7415341939925128e+28 +/- 1.258

#third epoch
#3.5617183193266224e+28 +/- 1.415
#Throughout this paper, we assumed a flat $\Lambda_{\rm{CDM}}$ cosmology with H$_{0}$ $=$ 71\,km\,s$^{-1}$ Mpc$^{-1}$, $\Omega_{m}$ $=$ 0.27, and $\Omega _{\Lambda}$ $=$ 0.73.

# %%
#from astropy.cosmology import WMAP5 as cosmo
from astropy.cosmology import FlatwCDM
cosmo = FlatwCDM(H0=71, Om0=0.27)
z = 0.218
ld = cosmo.luminosity_distance(z)
#flux = (0.0317 - 0.0063)*1e-3 #Jy 
flux = 0.405*1e-3 #Jy
f_p = flux *1e-23 
lum = (4*3.142*(ld.value*3.08568*10**24)**2*f_p)/(1+z)
lum  #3.5617183193266224e+28 +/- 1.415
# Out:
# 4.550460313335275e+29
